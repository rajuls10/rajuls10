# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/kaggle/input/dataset-mba-decision-after-bachelors/mba_decision_dataset.csv")

# %%
df = df.loc[
    ~((df['Age'] .isin([21, 22,23,24,25])) & (df['Current Job Title'] == 'Manager'))
]
#new age
df['modified-age'] = df['Age']
df.loc[(df['Age'] == 21) & (df['Years of Work Experience'] > 1), 'modified-age'] = df['Age'] + df['Years of Work Experience']
df.loc[(df['Age'] == 22) & (df['Years of Work Experience'] > 2), 'modified-age'] = df['Age'] + df['Years of Work Experience']
df.loc[(df['Age'] == 23) & (df['Years of Work Experience'] > 3), 'modified-age'] = df['Age'] + df['Years of Work Experience']
df.loc[(df['Age'] == 24) & (df['Years of Work Experience'] > 4), 'modified-age'] = df['Age'] + df['Years of Work Experience']
#......
df = df.loc[df['Annual Salary (Before MBA)']< df['Expected Post-MBA Salary'] ]
# NEW EXPERINCE 
df['new_exp'] = df['Years of Work Experience']
df.loc[(df['Has Management Experience'] == 'Yes') & (df['Years of Work Experience'] == 1) & (df['Current Job Title'] == 'Manager'), 'new_exp'] = df['Age'] - 21
df.loc[(df['Age'] > 24) & (df['Years of Work Experience'] == 0) & (df['Current Job Title'] == 'Manager'), 'new_exp'] = df['Age'] - 21
#n.....
df.loc[(df['modified-age'] < 25) & (df['modified-age'] > 21) & (df['new_exp'] == 0) & (df['Current Job Title'].isin(['Analyst', 'Engineer', 'Consultant'])), 'new_exp'] = 1

df=df.loc[~(df['Gender']=='Other')]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Has Management Experience'] = le.fit_transform(df['Has Management Experience'])
df['Location Preference (Post-MBA)'] = le.fit_transform(df['Location Preference (Post-MBA)'])
df['Online vs. On-Campus MBA'] = le.fit_transform(df['Online vs. On-Campus MBA'])

# %%
df['univ_grades'] = df['Undergraduate GPA'].apply(
    lambda x: 'C+' if 2.0 >= x <= 2.2 else
              'B-' if 2.3 >= x <= 2.6 else
              'B'  if 2.7 >= x <= 2.9 else
              'B+' if 3.0 >= x <= 3.2 else
              'A-' if 3.3 >= x <= 3.6 else
              'A'  
)

# %%
df.describe()
# Out:
#          Person ID          Age       Gender  Undergraduate GPA  \
# count  7610.000000  7610.000000  7610.000000        7610.000000
# mean   5003.447306    27.829041     0.532589           2.994679
# std    2888.812367     3.955738     0.498970           0.576368
# min       1.000000    21.000000     0.000000           2.000000
# 25%    2497.250000    25.000000     0.000000           2.490000
# 50%    4991.500000    28.000000     1.000000           3.000000
# 75%    7508.750000    31.000000     1.000000           3.490000
# max    9999.000000    34.000000     1.000000           4.000000
#
#        Years of Work Experience  Annual Salary (Before MBA)  \
# count               7610.000000                 7610.000000
# mean                   4.544415                71198.385414
# std                    2.860480                25122.328208
# min                    0.000000                30013.000000
# 25%                    2.000000                49557.000000
# 50%                    5.000000                69295.500000
# 75%                    7.000000                91984.250000
# max                    9.000000               119964.000000
#
#        Has Management Experience  GRE/GMAT Score  \
# count                7610.000000     7610.000000
# mean                    0.399869      523.498292
# std                     0.489903      157.812131
# min                     0.000000      250.000000
# 25%                     0.000000      388.000000
# 50%                     0.000000      524.000000
# 75%                     1.000000      659.000000
# max                     1.000000      799.000000
#
#        Undergrad University Ranking  Entrepreneurial Interest  \
# count                   7610.000000               7610.000000
# mean                     247.999080                  5.496702
# std                      144.786514                  2.582421
# min                        1.000000                  1.000000
# 25%                      123.000000                  3.300000
# 50%                      243.500000                  5.500000
# 75%                      375.000000                  7.700000
# max                      499.000000                 10.000000
#
#        Networking Importance  Expected Post-MBA Salary  \
# count            7610.000000               7610.000000
# mean                5.514691             138768.122733
# std                 2.600184              37502.596864
# min                 1.000000              60005.000000
# 25%                 3.200000             109606.250000
# 50%                 5.500000             140711.500000
# 75%                 7.700000             171060.750000
# max                10.000000             199999.000000
#
#        Location Preference (Post-MBA)  Online vs. On-Campus MBA  modified-age  \
# count                     7610.000000               7610.000000   7610.000000
# mean                         0.507753                  0.496189     28.821945
# std                          0.499973                  0.500018      3.269266
# min                          0.000000                  0.000000     21.000000
# 25%                          0.000000                  0.000000     26.000000
# 50%                          1.000000                  0.000000     29.000000
# 75%                          1.000000                  1.000000     32.000000
# max                          1.000000                  1.000000     34.000000
#
#            new_exp
# count  7610.000000
# mean      4.731669
# std       2.864718
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       7.000000
# max      13.000000

# %%
ndf = df[['modified-age','Undergraduate Major','Desired Post-MBA Role','Reason for MBA','MBA Funding Source','Current Job Title', 'new_exp','Years of Work Experience','Has Management Experience','Gender','Annual Salary (Before MBA)','Entrepreneurial Interest','Networking Importance','Undergraduate GPA', 'Location Preference (Post-MBA)','Online vs. On-Campus MBA','Decided to Pursue MBA?']]
ndf
# Out:
#       modified-age Undergraduate Major Desired Post-MBA Role  \
# 0               27                Arts       Finance Manager
# 1               24                Arts       Startup Founder
# 2               33            Business            Consultant
# 3               31         Engineering            Consultant
# 4               28            Business            Consultant
# ...            ...                 ...                   ...
# 9993            25                Arts       Startup Founder
# 9994            30            Business       Finance Manager
# 9996            30            Business            Consultant
# 9997            31           Economics            Consultant
# 9998            22                Arts    Marketing Director
#
#          Reason for MBA MBA Funding Source Current Job Title  new_exp  \
# 0      Entrepreneurship               Loan      Entrepreneur        8
# 1         Career Growth               Loan           Analyst        4
# 2     Skill Enhancement        Scholarship          Engineer        9
# 3      Entrepreneurship               Loan           Manager        1
# 4     Skill Enhancement               Loan      Entrepreneur        9
# ...                 ...                ...               ...      ...
# 9993  Skill Enhancement           Employer      Entrepreneur        8
# 9994         Networking        Self-funded      Entrepreneur        7
# 9996   Entrepreneurship        Scholarship           Manager        5
# 9997         Networking               Loan           Manager        8
# 9998         Networking        Self-funded          Engineer        1
#
#       Years of Work Experience  Has Management Experience  Gender  \
# 0                            8                          0       1
# 1                            4                          1       1
# 2                            9                          0       0
# 3                            1                          0       1
# 4                            9                          0       0
# ...                        ...                        ...     ...
# 9993                         8                          0       1
# 9994                         7                          1       1
# 9996                         5                          1       0
# 9997                         8                          1       0
# 9998                         1                          0       0
#
#       Annual Salary (Before MBA)  Entrepreneurial Interest  \
# 0                          90624                       7.9
# 1                          53576                       3.8
# 2                          79796                       6.7
# 3                         105956                       1.0
# 4                          96132                       9.5
# ...                          ...                       ...
# 9993                       76025                       1.2
# 9994                       92456                       1.6
# 9996                       82515                       7.4
# 9997                       34152                       6.8
# 9998                       61897                       5.7
#
#       Networking Importance  Undergraduate GPA  \
# 0                       7.6               3.18
# 1                       4.1               3.03
# 2                       5.5               3.66
# 3                       5.3               2.46
# 4                       4.9               2.75
# ...                     ...                ...
# 9993                    7.7               3.40
# 9994                    2.7               3.28
# 9996                    8.5               2.48
# 9997                    8.8               2.86
# 9998                    7.7               2.30
#
#       Location Preference (Post-MBA)  Online vs. On-Campus MBA  \
# 0                                  1                         0
# 1                                  1                         1
# 2                                  0                         1
# 3                                  1                         0
# 4                                  0                         1
# ...                              ...                       ...
# 9993                               0                         1
# 9994                               1                         1
# 9996                               0                         0
# 9997                               0                         0
# 9998                               1                         1
#
#      Decided to Pursue MBA?
# 0                       Yes
# 1                        No
# 2                        No
# 3                        No
# 4                       Yes
# ...                     ...
# 9993                    Yes
# 9994                    Yes
# 9996                     No
# 9997                    Yes
# 9998                    Yes
#
# [7610 rows x 17 columns]

# %%
x = ndf.iloc[:, :-1].values
y = ndf.iloc[:, -1].values

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1,2,3,4,5])], remainder='passthrough')
x = np.array(ct.fit_transform(x))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[   0  798]
#  [   1 1104]]
# 0.580136626379401

# %% [markdown]
# knn classification

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[267 531]
#  [353 752]]
# 0.535470310036784

# %% [markdown]
# kernal svm

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# SVC(random_state=0)

# %%
y_preds = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_preds)
# Out:
# [[267 531]
#  [353 752]]
# 0.581187598528639

# %% [markdown]
# naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)
y_prednb = classifier.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_prednb)
# Out:
# [[267 531]
#  [353 752]]
# 0.5459800315291645

# %% [markdown]
# descion tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
y_predd=classifier.predict(x_test)
cm=confusion_matrix(y_test,y_predd)
print(cm)
accuracy_score(y_test,y_predd)
# Out:
# [[319 479]
#  [449 656]]
# 0.512348922753547

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier(n_estimators=100,criterion='entropy',random_state=0)
classifier.fit(x_train,y_train)
y_rm=classifier.predict(x_test)

# %%
print(confusion_matrix(y_test,y_rm))
accuracy_score(y_test,y_rm)
# Out:
# [[113 685]
#  [141 964]]
# 0.5659485023646873
